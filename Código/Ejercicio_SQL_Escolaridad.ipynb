# %%
import pandas as pd
import requests
import sqlite3

# %%
# ===================================================================
# PASO 1: EXTRACCIÓN (EXTRACT) DE LOS DATOS
# ===================================================================

# La plataforma datos.gov.co usa la API de Socrata. Podemos usarla para
# descargar los datos directamente.
api_url = "https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000"

print(f"📥 Extrayendo datos desde: {api_url}")

try:
    response = requests.get(api_url)
    response.raise_for_status()  # Lanza un error si la petición falla
    data = response.json()
    df_raw = pd.DataFrame(data)
    print(f"✅ ¡Extracción exitosa! Se cargaron {len(df_raw)} filas.")
    display(df_raw.head())

except requests.exceptions.RequestException as e:
    print(f"❌ Error al extraer los datos: {e}")
    df_raw = pd.DataFrame()  # Creamos un DataFrame vacío para evitar errores posteriores

except Exception as e:
    print(f"❌ Ocurrió un error inesperado: {e}")
    df_raw = pd.DataFrame()
# Out:
# 📥 Extrayendo datos desde: https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000
# ✅ ¡Extracción exitosa! Se cargaron 14585 filas.
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
# 3  2023            97001        Mitú                  97       Vaupés
# 4  2023            97161      Caruru                  97       Vaupés
#
#   c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 0       3758  Antioquia (ETC)            503                   62.62
# 1       3830   Guaviare (ETC)           4438                   53.27
# 2       3830   Guaviare (ETC)           2014                   32.52
# 3       3831     Vaupés (ETC)          10986                   59.57
# 4       3831     Vaupés (ETC)           1228                    51.3
#
#   cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# 0          62.62  ...                 1.96                  16.51
# 1          53.27  ...                 7.11                   9.39
# 2          32.52  ...                 6.93                  14.13
# 3          59.57  ...                 4.04                   8.33
# 4           51.3  ...                 7.32                  15.28
#
#   reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 0              2.04       9.52                     0               10.46
# 1              1.75       9.34                  6.95               11.84
# 2              7.81       8.65                  6.67                9.04
# 3               4.6      16.18                  7.75               21.04
# 4              7.27       9.24                  2.86                7.62
#
#   repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 0                 13.76             2.04                      NaN
# 1                  8.48             3.16                      NaN
# 2                 10.25             1.54                      NaN
# 3                 13.84             7.18                      NaN
# 4                 14.85             3.64                      NaN
#
#   sedes_conectadas_a_internet
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 41 columns]

# %%
# Mostrar los departamentos únicos en formato de tabla
df_raw['departamento'].unique()
# Out:
# array(['Antioquia', 'Guaviare', 'Vaupés', 'Vichada', 'Guainía',
#        'Amazonas',
#        'Archipiélago de San Andrés, Providencia y Santa Catalina',
#        'Putumayo', 'Casanare', 'Arauca', 'Valle del Cauca', 'Tolima',
#        'Sucre', 'Santander', 'Risaralda', 'Quindio', 'Norte de Santander',
#        'Nariño', 'Meta', 'Magdalena', 'La Guajira', 'Huila', 'Chocó',
#        'Cundinamarca', 'Córdoba', 'Cesar', 'Cauca', 'Caquetá', 'Caldas',
#        'Boyacá', 'Bolívar', 'Bogotá, D.C.', 'Atlántico', 'NACIONAL',
#        'Archipiélago de San Andrés. Providencia y Santa Catalina',
#        'Bogotá D.C.'], dtype=object)

# %%
# Reemplazar los valores inconsistentes y normalizar los nombres de los departamentos
df_raw['departamento'] = df_raw['departamento'].replace({
    'Bogotá, D.C.': 'Bogotá D.C',  # Consolidar Bogotá
    'Bogotá D.C.': 'Bogotá D.C',  # Asegurarnos de que no haya variantes
    'Archipiélago de San Andrés. Providencia y Santa Catalina': 'Archipiélago de San Andrés, Providencia y Santa Catalina',  # Unificar nombre completo
    'Archipiélago de San Andrés, Providencia y Santa Catalina': 'Archipiélago de San Andrés, Providencia y Santa Catalina',  # Asegurar que ambos sean iguales
    'NACIONAL': 'No Aplica',  
})

# %%
# departamentos únicos después de la limpieza
departamentos_unicos = pd.DataFrame(df_raw['departamento'].unique(), columns=['Departamento'])
display(departamentos_unicos)
# Out:
#                                          Departamento
# 0                                           Antioquia
# 1                                            Guaviare
# 2                                              Vaupés
# 3                                             Vichada
# 4                                             Guainía
# 5                                            Amazonas
# 6   Archipiélago de San Andrés, Providencia y Sant...
# 7                                            Putumayo
# 8                                            Casanare
# 9                                              Arauca
# 10                                    Valle del Cauca
# 11                                             Tolima
# 12                                              Sucre
# 13                                          Santander
# 14                                          Risaralda
# 15                                            Quindio
# 16                                 Norte de Santander
# 17                                             Nariño
# 18                                               Meta
# 19                                          Magdalena
# 20                                         La Guajira
# 21                                              Huila
# 22                                              Chocó
# 23                                       Cundinamarca
# 24                                            Córdoba
# 25                                              Cesar
# 26                                              Cauca
# 27                                            Caquetá
# 28                                             Caldas
# 29                                             Boyacá
# 30                                            Bolívar
# 31                                         Bogotá D.C
# 32                                          Atlántico
# 33                                          No Aplica

# %%
df_raw = df_raw[df_raw['departamento'] != 'No Aplica']

departamentos_unicos = pd.DataFrame(df_raw['departamento'].unique(), columns=['Departamento'])
display(departamentos_unicos)
# Out:
#                                          Departamento
# 0                                           Antioquia
# 1                                            Guaviare
# 2                                              Vaupés
# 3                                             Vichada
# 4                                             Guainía
# 5                                            Amazonas
# 6   Archipiélago de San Andrés, Providencia y Sant...
# 7                                            Putumayo
# 8                                            Casanare
# 9                                              Arauca
# 10                                    Valle del Cauca
# 11                                             Tolima
# 12                                              Sucre
# 13                                          Santander
# 14                                          Risaralda
# 15                                            Quindio
# 16                                 Norte de Santander
# 17                                             Nariño
# 18                                               Meta
# 19                                          Magdalena
# 20                                         La Guajira
# 21                                              Huila
# 22                                              Chocó
# 23                                       Cundinamarca
# 24                                            Córdoba
# 25                                              Cesar
# 26                                              Cauca
# 27                                            Caquetá
# 28                                             Caldas
# 29                                             Boyacá
# 30                                            Bolívar
# 31                                         Bogotá D.C
# 32                                          Atlántico

# %%
df_raw.columns
# Out:
# Index(['a_o', 'c_digo_municipio', 'municipio', 'c_digo_departamento',
#        'departamento', 'c_digo_etc', 'etc', 'poblaci_n_5_16',
#        'tasa_matriculaci_n_5_16', 'cobertura_neta',
#        'cobertura_neta_transici_n', 'cobertura_neta_primaria',
#        'cobertura_neta_secundaria', 'cobertura_neta_media', 'cobertura_bruta',
#        'cobertura_bruta_transici_n', 'cobertura_bruta_primaria',
#        'cobertura_bruta_secundaria', 'cobertura_bruta_media', 'deserci_n',
#        'deserci_n_transici_n', 'deserci_n_primaria', 'deserci_n_secundaria',
#        'deserci_n_media', 'aprobaci_n', 'aprobaci_n_transici_n',
#        'aprobaci_n_primaria', 'aprobaci_n_secundaria', 'aprobaci_n_media',
#        'reprobaci_n', 'reprobaci_n_transici_n', 'reprobaci_n_primaria',
#        'reprobaci_n_secundaria', 'reprobaci_n_media', 'repitencia',
#        'repitencia_transici_n', 'repitencia_primaria', 'repitencia_secundaria',
#        'repitencia_media', 'tama_o_promedio_de_grupo',
#        'sedes_conectadas_a_internet'],
#       dtype='object')

# %%
# eliminar etc
pd.set_option('display.max_columns', None)

# df_raw.drop(columns=['etc'], inplace=True) ya se elimino

# %%
df_raw.drop(columns=['c_digo_etc'], inplace=True)

# %%
display(df_raw.head())
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
# 3  2023            97001        Mitú                  97       Vaupés
# 4  2023            97161      Caruru                  97       Vaupés
#
#   poblaci_n_5_16 tasa_matriculaci_n_5_16 cobertura_neta  \
# 0            503                   62.62          62.62
# 1           4438                   53.27          53.27
# 2           2014                   32.52          32.52
# 3          10986                   59.57          59.57
# 4           1228                    51.3           51.3
#
#   cobertura_neta_transici_n cobertura_neta_primaria cobertura_neta_secundaria  \
# 0                     44.19                   63.33                     51.53
# 1                     33.91                   48.89                      44.9
# 2                     17.58                   25.33                     26.43
# 3                     42.76                   55.95                     43.51
# 4                     76.32                   52.29                     33.71
#
#   cobertura_neta_media cobertura_bruta cobertura_bruta_transici_n  \
# 0                40.23            66.8                      58.14
# 1                 21.3           62.98                       54.2
# 2                10.75           38.58                      36.36
# 3                17.06           70.65                       64.9
# 4                11.94           55.54                      92.11
#
#   cobertura_bruta_primaria cobertura_bruta_secundaria cobertura_bruta_media  \
# 0                    72.86                      66.87                 56.32
# 1                    65.19                       69.6                 48.54
# 2                    37.28                       46.1                 26.16
# 3                    76.96                      72.92                 53.12
# 4                    65.21                      51.12                 27.36
#
#   deserci_n deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 0      1.19                    0               1.31                    0
# 1      5.56                 6.95               4.99                 6.11
# 2      7.85                   15               8.43                 6.36
# 3      3.95                 2.27               1.84                 6.77
# 4      8.36                 4.29               3.05                15.72
#
#   deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 0            4.08      92.26                     0               96.73
# 1            5.26      87.67                     0                87.9
# 2            4.69      82.68                  3.33               84.64
# 3            5.47      90.71                  0.57               94.12
# 4           14.55       82.4                     0               89.63
#
#   aprobaci_n_secundaria aprobaci_n_media reprobaci_n reprobaci_n_transici_n  \
# 0                 83.49            93.88        6.55                      0
# 1                  84.5            92.98        6.78                      0
# 2                 79.51             87.5        9.47                   3.33
# 3                 84.91            89.93        5.34                   0.57
# 4                    69            78.18        9.24                      0
#
#   reprobaci_n_primaria reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 0                 1.96                  16.51              2.04       9.52
# 1                 7.11                   9.39              1.75       9.34
# 2                 6.93                  14.13              7.81       8.65
# 3                 4.04                   8.33               4.6      16.18
# 4                 7.32                  15.28              7.27       9.24
#
#   repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 0                     0               10.46                 13.76
# 1                  6.95               11.84                  8.48
# 2                  6.67                9.04                 10.25
# 3                  7.75               21.04                 13.84
# 4                  2.86                7.62                 14.85
#
#   repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet
# 0             2.04                      NaN                         NaN
# 1             3.16                      NaN                         NaN
# 2             1.54                      NaN                         NaN
# 3             7.18                      NaN                         NaN
# 4             3.64                      NaN                         NaN

# %%
# Función para validar si los valores están dentro de un rango permitido (0 a 100)
def validate_range(value):
    if isinstance(value, (int, float)):
        if 0 <= value <= 100:
            return value
        else:
            return None  # Si está fuera de rango, lo convertimos en NaN
    return value

# Aplicamos esta validación a todas las columnas numéricas
columnas_numericas = [
    'poblaci_n_5_16', 'tasa_matriculaci_n_5_16', 'cobertura_neta', 'cobertura_neta_transici_n', 'cobertura_neta_primaria',
    'cobertura_neta_secundaria', 'cobertura_neta_media', 'cobertura_bruta', 'cobertura_bruta_transici_n', 'cobertura_bruta_primaria',
    'cobertura_bruta_secundaria', 'cobertura_bruta_media', 'deserci_n', 'deserci_n_transici_n', 'deserci_n_primaria',
    'deserci_n_secundaria', 'deserci_n_media', 'aprobaci_n', 'aprobaci_n_transici_n', 'aprobaci_n_primaria', 'aprobaci_n_secundaria',
    'aprobaci_n_media', 'reprobaci_n', 'reprobaci_n_transici_n', 'reprobaci_n_primaria', 'reprobaci_n_secundaria', 'reprobaci_n_media',
    'repitencia', 'repitencia_transici_n', 'repitencia_primaria', 'repitencia_secundaria', 'repitencia_media', 'tama_o_promedio_de_grupo',
    'sedes_conectadas_a_internet'
]

# Aplicamos la validación a cada columna numérica
for col in columnas_numericas:
    df_raw[col] = df_raw[col].apply(validate_range)

# Mostrar las primeras filas después de la validación
display(df_raw.head())
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
# 3  2023            97001        Mitú                  97       Vaupés
# 4  2023            97161      Caruru                  97       Vaupés
#
#   poblaci_n_5_16 tasa_matriculaci_n_5_16 cobertura_neta  \
# 0            503                   62.62          62.62
# 1           4438                   53.27          53.27
# 2           2014                   32.52          32.52
# 3          10986                   59.57          59.57
# 4           1228                    51.3           51.3
#
#   cobertura_neta_transici_n cobertura_neta_primaria cobertura_neta_secundaria  \
# 0                     44.19                   63.33                     51.53
# 1                     33.91                   48.89                      44.9
# 2                     17.58                   25.33                     26.43
# 3                     42.76                   55.95                     43.51
# 4                     76.32                   52.29                     33.71
#
#   cobertura_neta_media cobertura_bruta cobertura_bruta_transici_n  \
# 0                40.23            66.8                      58.14
# 1                 21.3           62.98                       54.2
# 2                10.75           38.58                      36.36
# 3                17.06           70.65                       64.9
# 4                11.94           55.54                      92.11
#
#   cobertura_bruta_primaria cobertura_bruta_secundaria cobertura_bruta_media  \
# 0                    72.86                      66.87                 56.32
# 1                    65.19                       69.6                 48.54
# 2                    37.28                       46.1                 26.16
# 3                    76.96                      72.92                 53.12
# 4                    65.21                      51.12                 27.36
#
#   deserci_n deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 0      1.19                    0               1.31                    0
# 1      5.56                 6.95               4.99                 6.11
# 2      7.85                   15               8.43                 6.36
# 3      3.95                 2.27               1.84                 6.77
# 4      8.36                 4.29               3.05                15.72
#
#   deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 0            4.08      92.26                     0               96.73
# 1            5.26      87.67                     0                87.9
# 2            4.69      82.68                  3.33               84.64
# 3            5.47      90.71                  0.57               94.12
# 4           14.55       82.4                     0               89.63
#
#   aprobaci_n_secundaria aprobaci_n_media reprobaci_n reprobaci_n_transici_n  \
# 0                 83.49            93.88        6.55                      0
# 1                  84.5            92.98        6.78                      0
# 2                 79.51             87.5        9.47                   3.33
# 3                 84.91            89.93        5.34                   0.57
# 4                    69            78.18        9.24                      0
#
#   reprobaci_n_primaria reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 0                 1.96                  16.51              2.04       9.52
# 1                 7.11                   9.39              1.75       9.34
# 2                 6.93                  14.13              7.81       8.65
# 3                 4.04                   8.33               4.6      16.18
# 4                 7.32                  15.28              7.27       9.24
#
#   repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 0                     0               10.46                 13.76
# 1                  6.95               11.84                  8.48
# 2                  6.67                9.04                 10.25
# 3                  7.75               21.04                 13.84
# 4                  2.86                7.62                 14.85
#
#   repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet
# 0             2.04                     None                        None
# 1             3.16                     None                        None
# 2             1.54                     None                        None
# 3             7.18                     None                        None
# 4             3.64                     None                        None

# %%
# Convertirtipo float 
df_raw[columnas_numericas] = df_raw[columnas_numericas].apply(pd.to_numeric, errors='coerce')

display(df_raw.head())
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
# 3  2023            97001        Mitú                  97       Vaupés
# 4  2023            97161      Caruru                  97       Vaupés
#
#    poblaci_n_5_16  tasa_matriculaci_n_5_16  cobertura_neta  \
# 0           503.0                    62.62           62.62
# 1          4438.0                    53.27           53.27
# 2          2014.0                    32.52           32.52
# 3         10986.0                    59.57           59.57
# 4          1228.0                    51.30           51.30
#
#    cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0                      44.19                    63.33
# 1                      33.91                    48.89
# 2                      17.58                    25.33
# 3                      42.76                    55.95
# 4                      76.32                    52.29
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                      51.53                 40.23            66.80
# 1                      44.90                 21.30            62.98
# 2                      26.43                 10.75            38.58
# 3                      43.51                 17.06            70.65
# 4                      33.71                 11.94            55.54
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                       58.14                     72.86
# 1                       54.20                     65.19
# 2                       36.36                     37.28
# 3                       64.90                     76.96
# 4                       92.11                     65.21
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                       66.87                  56.32       1.19
# 1                       69.60                  48.54       5.56
# 2                       46.10                  26.16       7.85
# 3                       72.92                  53.12       3.95
# 4                       51.12                  27.36       8.36
#
#    deserci_n_transici_n  deserci_n_primaria  deserci_n_secundaria  \
# 0                  0.00                1.31                  0.00
# 1                  6.95                4.99                  6.11
# 2                 15.00                8.43                  6.36
# 3                  2.27                1.84                  6.77
# 4                  4.29                3.05                 15.72
#
#    deserci_n_media  aprobaci_n  aprobaci_n_transici_n  aprobaci_n_primaria  \
# 0             4.08       92.26                   0.00                96.73
# 1             5.26       87.67                   0.00                87.90
# 2             4.69       82.68                   3.33                84.64
# 3             5.47       90.71                   0.57                94.12
# 4            14.55       82.40                   0.00                89.63
#
#    aprobaci_n_secundaria  aprobaci_n_media  reprobaci_n  \
# 0                  83.49             93.88         6.55
# 1                  84.50             92.98         6.78
# 2                  79.51             87.50         9.47
# 3                  84.91             89.93         5.34
# 4                  69.00             78.18         9.24
#
#    reprobaci_n_transici_n  reprobaci_n_primaria  reprobaci_n_secundaria  \
# 0                    0.00                  1.96                   16.51
# 1                    0.00                  7.11                    9.39
# 2                    3.33                  6.93                   14.13
# 3                    0.57                  4.04                    8.33
# 4                    0.00                  7.32                   15.28
#
#    reprobaci_n_media  repitencia  repitencia_transici_n  repitencia_primaria  \
# 0               2.04        9.52                   0.00                10.46
# 1               1.75        9.34                   6.95                11.84
# 2               7.81        8.65                   6.67                 9.04
# 3               4.60       16.18                   7.75                21.04
# 4               7.27        9.24                   2.86                 7.62
#
#    repitencia_secundaria  repitencia_media  tama_o_promedio_de_grupo  \
# 0                  13.76              2.04                       NaN
# 1                   8.48              3.16                       NaN
# 2                  10.25              1.54                       NaN
# 3                  13.84              7.18                       NaN
# 4                  14.85              3.64                       NaN
#
#    sedes_conectadas_a_internet
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN

# %%
# valores nulos con la mediana de cada columna numérica
for col in columnas_numericas:
    df_raw[col].fillna(df_raw[col].median(), inplace=True)


display(df_raw.head())
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
# C:\Users\laura\AppData\Local\Temp\ipykernel_15576\2565576813.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_raw[col].fillna(df_raw[col].median(), inplace=True)
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
# 3  2023            97001        Mitú                  97       Vaupés
# 4  2023            97161      Caruru                  97       Vaupés
#
#    poblaci_n_5_16  tasa_matriculaci_n_5_16  cobertura_neta  \
# 0           503.0                    62.62           62.62
# 1          4438.0                    53.27           53.27
# 2          2014.0                    32.52           32.52
# 3         10986.0                    59.57           59.57
# 4          1228.0                    51.30           51.30
#
#    cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0                      44.19                    63.33
# 1                      33.91                    48.89
# 2                      17.58                    25.33
# 3                      42.76                    55.95
# 4                      76.32                    52.29
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                      51.53                 40.23            66.80
# 1                      44.90                 21.30            62.98
# 2                      26.43                 10.75            38.58
# 3                      43.51                 17.06            70.65
# 4                      33.71                 11.94            55.54
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                       58.14                     72.86
# 1                       54.20                     65.19
# 2                       36.36                     37.28
# 3                       64.90                     76.96
# 4                       92.11                     65.21
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                       66.87                  56.32       1.19
# 1                       69.60                  48.54       5.56
# 2                       46.10                  26.16       7.85
# 3                       72.92                  53.12       3.95
# 4                       51.12                  27.36       8.36
#
#    deserci_n_transici_n  deserci_n_primaria  deserci_n_secundaria  \
# 0                  0.00                1.31                  0.00
# 1                  6.95                4.99                  6.11
# 2                 15.00                8.43                  6.36
# 3                  2.27                1.84                  6.77
# 4                  4.29                3.05                 15.72
#
#    deserci_n_media  aprobaci_n  aprobaci_n_transici_n  aprobaci_n_primaria  \
# 0             4.08       92.26                   0.00                96.73
# 1             5.26       87.67                   0.00                87.90
# 2             4.69       82.68                   3.33                84.64
# 3             5.47       90.71                   0.57                94.12
# 4            14.55       82.40                   0.00                89.63
#
#    aprobaci_n_secundaria  aprobaci_n_media  reprobaci_n  \
# 0                  83.49             93.88         6.55
# 1                  84.50             92.98         6.78
# 2                  79.51             87.50         9.47
# 3                  84.91             89.93         5.34
# 4                  69.00             78.18         9.24
#
#    reprobaci_n_transici_n  reprobaci_n_primaria  reprobaci_n_secundaria  \
# 0                    0.00                  1.96                   16.51
# 1                    0.00                  7.11                    9.39
# 2                    3.33                  6.93                   14.13
# 3                    0.57                  4.04                    8.33
# 4                    0.00                  7.32                   15.28
#
#    reprobaci_n_media  repitencia  repitencia_transici_n  repitencia_primaria  \
# 0               2.04        9.52                   0.00                10.46
# 1               1.75        9.34                   6.95                11.84
# 2               7.81        8.65                   6.67                 9.04
# 3               4.60       16.18                   7.75                21.04
# 4               7.27        9.24                   2.86                 7.62
#
#    repitencia_secundaria  repitencia_media  tama_o_promedio_de_grupo  \
# 0                  13.76              2.04                     23.96
# 1                   8.48              3.16                     23.96
# 2                  10.25              1.54                     23.96
# 3                  13.84              7.18                     23.96
# 4                  14.85              3.64                     23.96
#
#    sedes_conectadas_a_internet
# 0                        28.13
# 1                        28.13
# 2                        28.13
# 3                        28.13
# 4                        28.13

# %%
# Valores nulos prueba
df_raw.isnull().sum().sort_values(ascending=False)
# Out:
# a_o                            0
# c_digo_municipio               0
# municipio                      0
# c_digo_departamento            0
# departamento                   0
# poblaci_n_5_16                 0
# tasa_matriculaci_n_5_16        0
# cobertura_neta                 0
# cobertura_neta_transici_n      0
# cobertura_neta_primaria        0
# cobertura_neta_secundaria      0
# cobertura_neta_media           0
# cobertura_bruta                0
# cobertura_bruta_transici_n     0
# cobertura_bruta_primaria       0
# cobertura_bruta_secundaria     0
# cobertura_bruta_media          0
# deserci_n                      0
# deserci_n_transici_n           0
# deserci_n_primaria             0
# deserci_n_secundaria           0
# deserci_n_media                0
# aprobaci_n                     0
# aprobaci_n_transici_n          0
# aprobaci_n_primaria            0
# aprobaci_n_secundaria          0
# aprobaci_n_media               0
# reprobaci_n                    0
# reprobaci_n_transici_n         0
# reprobaci_n_primaria           0
# reprobaci_n_secundaria         0
# reprobaci_n_media              0
# repitencia                     0
# repitencia_transici_n          0
# repitencia_primaria            0
# repitencia_secundaria          0
# repitencia_media               0
# tama_o_promedio_de_grupo       0
# sedes_conectadas_a_internet    0
# dtype: int64

# %%
df_raw.describe()
# Out:
#        poblaci_n_5_16  tasa_matriculaci_n_5_16  cobertura_neta  \
# count    1.458200e+04             14582.000000    14582.000000
# mean     8.221956e+03                84.992045       85.577053
# std      4.452569e+04                18.478310       16.825936
# min      1.000000e+00                 0.000000        0.000000
# 25%      1.165000e+03                74.950000       76.962500
# 50%      2.639000e+03                85.330000       86.400000
# 75%      5.862000e+03                95.307500       94.477500
# max      1.479334e+06               279.030000      264.540000
#
#        cobertura_neta_transici_n  cobertura_neta_primaria  \
# count               14582.000000             14582.000000
# mean                   57.704857                82.585241
# std                    16.150646                17.111552
# min                     0.000000                 0.000000
# 25%                    47.590000                73.310000
# 50%                    57.900000                82.840000
# 75%                    68.000000                91.867500
# max                   150.470000               254.960000
#
#        cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# count               14582.000000          14582.000000     14582.000000
# mean                   69.926184             40.758024        97.579165
# std                    18.746043             15.570022        21.208524
# min                     0.000000              0.000000         0.000000
# 25%                    60.500000             31.192500        85.730000
# 50%                    70.900000             41.180000        97.490000
# 75%                    80.500000             50.500000       109.190000
# max                   229.440000            170.260000       286.920000
#
#        cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# count                14582.000000              14582.000000
# mean                    87.135333                105.093967
# std                     25.453826                 25.174776
# min                      0.000000                  0.000000
# 25%                     71.560000                 89.910000
# 50%                     85.220000                103.320000
# 75%                    100.000000                117.600000
# max                    259.290000                326.400000
#
#        cobertura_bruta_secundaria  cobertura_bruta_media     deserci_n  \
# count                14582.000000           14582.000000  14582.000000
# mean                   101.135100              75.865937      3.487122
# std                     25.708737              26.856202      2.161911
# min                      0.000000               0.000000      0.000000
# 25%                     86.642500              59.760000      1.950000
# 50%                    101.535000              75.250000      3.130000
# 75%                    115.630000              90.240000      4.640000
# max                    301.710000             489.620000     27.900000
#
#        deserci_n_transici_n  deserci_n_primaria  deserci_n_secundaria  \
# count          14582.000000        14582.000000          14582.000000
# mean               3.457339            2.749975              4.568885
# std                2.688775            2.031311              3.074556
# min                0.000000            0.000000              0.000000
# 25%                1.630000            1.280000              2.380000
# 50%                3.000000            2.320000              4.040000
# 75%                4.710000            3.750000              6.150000
# max               42.860000           18.310000             47.140000
#
#        deserci_n_media    aprobaci_n  aprobaci_n_transici_n  \
# count     14582.000000  14582.000000           14582.000000
# mean          3.435997     91.627448               0.483803
# std           3.190088      5.162328               1.648629
# min           0.000000      0.000000               0.000000
# 25%           1.690000     88.450000               0.000000
# 50%           2.850000     92.020000               0.000000
# 75%           4.400000     95.580000               0.210000
# max          62.500000    100.000000              52.710000
#
#        aprobaci_n_primaria  aprobaci_n_secundaria  aprobaci_n_media  \
# count         14582.000000           14582.000000      14582.000000
# mean             93.233581              88.379478         92.167227
# std               5.041247               7.858355          6.867764
# min               0.000000               0.000000          0.000000
# 25%              90.580000              83.660000         89.470000
# 50%              93.870000              89.100000         93.290000
# 75%              96.940000              94.440000         96.410000
# max             100.000000             100.000000        100.000000
#
#         reprobaci_n  reprobaci_n_transici_n  reprobaci_n_primaria  \
# count  14582.000000            14582.000000          14582.000000
# mean       4.756870                0.483803              3.881868
# std        3.987597                1.648629              3.790051
# min        0.000000                0.000000              0.000000
# 25%        0.950000                0.000000              0.430000
# 50%        4.520000                0.000000              3.330000
# 75%        7.397500                0.210000              5.980000
# max       49.390000               52.710000             51.970000
#
#        reprobaci_n_secundaria  reprobaci_n_media    repitencia  \
# count            14582.000000       14582.000000  14582.000000
# mean                 6.805669           4.121498      3.288975
# std                  6.131181           4.192027      3.355109
# min                  0.000000           0.000000      0.000000
# 25%                  0.762500           0.682500      0.730000
# 50%                  6.160000           3.110000      2.160000
# 75%                 10.790000           6.360000      5.047500
# max                 76.970000          67.860000     37.470000
#
#        repitencia_transici_n  repitencia_primaria  repitencia_secundaria  \
# count           14582.000000         14582.000000           14582.000000
# mean                0.933135             3.157061               4.310828
# std                 2.404131             3.627971               4.527894
# min                 0.000000             0.000000               0.000000
# 25%                 0.000000             0.600000               0.750000
# 50%                 0.000000             1.880000               2.740000
# 75%                 0.920000             4.550000               6.770000
# max                50.000000            50.760000              55.070000
#
#        repitencia_media  tama_o_promedio_de_grupo  sedes_conectadas_a_internet
# count      14582.000000              14582.000000                 14582.000000
# mean           1.690343                 23.955956                    31.699926
# std            2.274741                  5.551520                    19.400318
# min            0.000000                  3.000000                     0.000000
# 25%            0.000000                 23.680000                    25.810000
# 50%            0.870000                 23.960000                    28.130000
# 75%            2.530000                 24.250000                    30.417500
# max           36.450000                 54.030000                   100.000000

# %% [markdown]
# La cobertura educativa y la tasa de matrícula pueden exceder el 100% debido a fenómenos como la extraedad (cuando los estudiantes están fuera del rango de edad teórica para un nivel educativo) y los flujos migratorios no reflejados en las proyecciones poblacionales. Este comportamiento es frecuente en regiones con alta demanda social o movimientos migratorios significativos.

# %%
# Verificar y convertir columnas con fechas
df_raw['a_o'] = pd.to_datetime(df_raw['a_o'], errors='coerce')

display(df_raw.head())
# Out:
#          a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0 2023-01-01            05004    Abriaquí                  05    Antioquia
# 1 2023-01-01            95025  El Retorno                  95     Guaviare
# 2 2023-01-01            95200  Miraflores                  95     Guaviare
# 3 2023-01-01            97001        Mitú                  97       Vaupés
# 4 2023-01-01            97161      Caruru                  97       Vaupés
#
#    poblaci_n_5_16  tasa_matriculaci_n_5_16  cobertura_neta  \
# 0           503.0                    62.62           62.62
# 1          4438.0                    53.27           53.27
# 2          2014.0                    32.52           32.52
# 3         10986.0                    59.57           59.57
# 4          1228.0                    51.30           51.30
#
#    cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0                      44.19                    63.33
# 1                      33.91                    48.89
# 2                      17.58                    25.33
# 3                      42.76                    55.95
# 4                      76.32                    52.29
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                      51.53                 40.23            66.80
# 1                      44.90                 21.30            62.98
# 2                      26.43                 10.75            38.58
# 3                      43.51                 17.06            70.65
# 4                      33.71                 11.94            55.54
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                       58.14                     72.86
# 1                       54.20                     65.19
# 2                       36.36                     37.28
# 3                       64.90                     76.96
# 4                       92.11                     65.21
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                       66.87                  56.32       1.19
# 1                       69.60                  48.54       5.56
# 2                       46.10                  26.16       7.85
# 3                       72.92                  53.12       3.95
# 4                       51.12                  27.36       8.36
#
#    deserci_n_transici_n  deserci_n_primaria  deserci_n_secundaria  \
# 0                  0.00                1.31                  0.00
# 1                  6.95                4.99                  6.11
# 2                 15.00                8.43                  6.36
# 3                  2.27                1.84                  6.77
# 4                  4.29                3.05                 15.72
#
#    deserci_n_media  aprobaci_n  aprobaci_n_transici_n  aprobaci_n_primaria  \
# 0             4.08       92.26                   0.00                96.73
# 1             5.26       87.67                   0.00                87.90
# 2             4.69       82.68                   3.33                84.64
# 3             5.47       90.71                   0.57                94.12
# 4            14.55       82.40                   0.00                89.63
#
#    aprobaci_n_secundaria  aprobaci_n_media  reprobaci_n  \
# 0                  83.49             93.88         6.55
# 1                  84.50             92.98         6.78
# 2                  79.51             87.50         9.47
# 3                  84.91             89.93         5.34
# 4                  69.00             78.18         9.24
#
#    reprobaci_n_transici_n  reprobaci_n_primaria  reprobaci_n_secundaria  \
# 0                    0.00                  1.96                   16.51
# 1                    0.00                  7.11                    9.39
# 2                    3.33                  6.93                   14.13
# 3                    0.57                  4.04                    8.33
# 4                    0.00                  7.32                   15.28
#
#    reprobaci_n_media  repitencia  repitencia_transici_n  repitencia_primaria  \
# 0               2.04        9.52                   0.00                10.46
# 1               1.75        9.34                   6.95                11.84
# 2               7.81        8.65                   6.67                 9.04
# 3               4.60       16.18                   7.75                21.04
# 4               7.27        9.24                   2.86                 7.62
#
#    repitencia_secundaria  repitencia_media  tama_o_promedio_de_grupo  \
# 0                  13.76              2.04                     23.96
# 1                   8.48              3.16                     23.96
# 2                  10.25              1.54                     23.96
# 3                  13.84              7.18                     23.96
# 4                  14.85              3.64                     23.96
#
#    sedes_conectadas_a_internet
# 0                        28.13
# 1                        28.13
# 2                        28.13
# 3                        28.13
# 4                        28.13

# %%
#categorías únicas en la columna 'departamento'
departamentos_unicos = df_raw['departamento'].unique()
print(departamentos_unicos)
# Out:
# ['Antioquia' 'Guaviare' 'Vaupés' 'Vichada' 'Guainía' 'Amazonas'
#  'Archipiélago de San Andrés, Providencia y Santa Catalina' 'Putumayo'
#  'Casanare' 'Arauca' 'Valle del Cauca' 'Tolima' 'Sucre' 'Santander'
#  'Risaralda' 'Quindio' 'Norte de Santander' 'Nariño' 'Meta' 'Magdalena'
#  'La Guajira' 'Huila' 'Chocó' 'Cundinamarca' 'Córdoba' 'Cesar' 'Cauca'
#  'Caquetá' 'Caldas' 'Boyacá' 'Bolívar' 'Bogotá D.C' 'Atlántico']

# %%
# verificar las categorías únicas en la columna 'municipio'
df_raw['municipio'].unique()
# Out:
# array(['Abriaquí', 'El Retorno', 'Miraflores', ..., 'Alejandría',
#        'Bogotá D.C.', 'Mapiripana'], shape=(1036,), dtype=object)

# %%
# Agrupar por 'c_digo_municipio' y contar cuántos nombres de 'municipio' diferentes hay
municipios_duplicados = df_raw.groupby('c_digo_municipio')['municipio'].nunique()

# Filtrar los municipios que tienen más de un nombre asociado
municipios_con_duplicados = municipios_duplicados[municipios_duplicados > 1]

# Mostrar los municipios con duplicados
print("Municipios con duplicados (más de un nombre asociado):")
print(municipios_con_duplicados)
# Out:
# Municipios con duplicados (más de un nombre asociado):
# c_digo_municipio
# 11001    2
# Name: municipio, dtype: int64

# %%
municipios_duplicados_11001 = df_raw[df_raw['c_digo_municipio'] == '11001']
display(municipios_duplicados_11001[['c_digo_municipio', 'municipio']])
# Out:
#       c_digo_municipio     municipio
# 974              11001  Bogotá, D.C.
# 2088             11001  Bogotá, D.C.
# 3215             11001  Bogotá, D.C.
# 3653             11001   Bogotá D.C.
# 5457             11001  Bogotá, D.C.
# 6570             11001  Bogotá, D.C.
# 7709             11001  Bogotá, D.C.
# 8007             11001  Bogotá, D.C.
# 9941             11001  Bogotá, D.C.
# 11067            11001  Bogotá, D.C.
# 12189            11001  Bogotá, D.C.
# 13306            11001  Bogotá, D.C.
# 14438            11001  Bogotá, D.C.

# %%
bogota_correccion = df_raw[df_raw['municipio'] == 'Bogotá, D.C.']
display(bogota_correccion[['c_digo_municipio', 'municipio']])
# Out:
#       c_digo_municipio     municipio
# 974              11001  Bogotá, D.C.
# 2088             11001  Bogotá, D.C.
# 3215             11001  Bogotá, D.C.
# 3653             11001  Bogotá, D.C.
# 5457             11001  Bogotá, D.C.
# 6570             11001  Bogotá, D.C.
# 7709             11001  Bogotá, D.C.
# 8007             11001  Bogotá, D.C.
# 9941             11001  Bogotá, D.C.
# 11067            11001  Bogotá, D.C.
# 12189            11001  Bogotá, D.C.
# 13306            11001  Bogotá, D.C.
# 14438            11001  Bogotá, D.C.

# %% [markdown]
# ## Convertir Categoria

# %%
df_raw['departamento'] = df_raw['departamento'].astype('category')
df_raw['municipio'] = df_raw['municipio'].astype('category')

# Verificar el tipo de las columnas después de la conversión
print(df_raw.dtypes)
# Out:
# a_o                            datetime64[ns]
# c_digo_municipio                       object
# municipio                            category
# c_digo_departamento                    object
# departamento                         category
# poblaci_n_5_16                        float64
# tasa_matriculaci_n_5_16               float64
# cobertura_neta                        float64
# cobertura_neta_transici_n             float64
# cobertura_neta_primaria               float64
# cobertura_neta_secundaria             float64
# cobertura_neta_media                  float64
# cobertura_bruta                       float64
# cobertura_bruta_transici_n            float64
# cobertura_bruta_primaria              float64
# cobertura_bruta_secundaria            float64
# cobertura_bruta_media                 float64
# deserci_n                             float64
# deserci_n_transici_n                  float64
# deserci_n_primaria                    float64
# deserci_n_secundaria                  float64
# deserci_n_media                       float64
# aprobaci_n                            float64
# aprobaci_n_transici_n                 float64
# aprobaci_n_primaria                   float64
# aprobaci_n_secundaria                 float64
# aprobaci_n_media                      float64
# reprobaci_n                           float64
# reprobaci_n_transici_n                float64
# reprobaci_n_primaria                  float64
# reprobaci_n_secundaria                float64
# reprobaci_n_media                     float64
# repitencia                            float64
# repitencia_transici_n                 float64
# repitencia_primaria                   float64
# repitencia_secundaria                 float64
# repitencia_media                      float64
# tama_o_promedio_de_grupo              float64
# sedes_conectadas_a_internet           float64
# dtype: object

# %%
df_raw.head(3)
# Out:
#          a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0 2023-01-01            05004    Abriaquí                  05    Antioquia
# 1 2023-01-01            95025  El Retorno                  95     Guaviare
# 2 2023-01-01            95200  Miraflores                  95     Guaviare
#
#    poblaci_n_5_16  tasa_matriculaci_n_5_16  cobertura_neta  \
# 0           503.0                    62.62           62.62
# 1          4438.0                    53.27           53.27
# 2          2014.0                    32.52           32.52
#
#    cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0                      44.19                    63.33
# 1                      33.91                    48.89
# 2                      17.58                    25.33
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                      51.53                 40.23            66.80
# 1                      44.90                 21.30            62.98
# 2                      26.43                 10.75            38.58
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                       58.14                     72.86
# 1                       54.20                     65.19
# 2                       36.36                     37.28
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                       66.87                  56.32       1.19
# 1                       69.60                  48.54       5.56
# 2                       46.10                  26.16       7.85
#
#    deserci_n_transici_n  deserci_n_primaria  deserci_n_secundaria  \
# 0                  0.00                1.31                  0.00
# 1                  6.95                4.99                  6.11
# 2                 15.00                8.43                  6.36
#
#    deserci_n_media  aprobaci_n  aprobaci_n_transici_n  aprobaci_n_primaria  \
# 0             4.08       92.26                   0.00                96.73
# 1             5.26       87.67                   0.00                87.90
# 2             4.69       82.68                   3.33                84.64
#
#    aprobaci_n_secundaria  aprobaci_n_media  reprobaci_n  \
# 0                  83.49             93.88         6.55
# 1                  84.50             92.98         6.78
# 2                  79.51             87.50         9.47
#
#    reprobaci_n_transici_n  reprobaci_n_primaria  reprobaci_n_secundaria  \
# 0                    0.00                  1.96                   16.51
# 1                    0.00                  7.11                    9.39
# 2                    3.33                  6.93                   14.13
#
#    reprobaci_n_media  repitencia  repitencia_transici_n  repitencia_primaria  \
# 0               2.04        9.52                   0.00                10.46
# 1               1.75        9.34                   6.95                11.84
# 2               7.81        8.65                   6.67                 9.04
#
#    repitencia_secundaria  repitencia_media  tama_o_promedio_de_grupo  \
# 0                  13.76              2.04                     23.96
# 1                   8.48              3.16                     23.96
# 2                  10.25              1.54                     23.96
#
#    sedes_conectadas_a_internet
# 0                        28.13
# 1                        28.13
# 2                        28.13

# %%
df_raw['tasa_matriculaci_n_5_16'] = pd.to_numeric(df_raw['tasa_matriculaci_n_5_16'], errors='coerce')
df_raw['cobertura_neta'] = pd.to_numeric(df_raw['cobertura_neta'], errors='coerce')
df_raw['a_o'] = pd.to_datetime(df_raw['a_o'], format='%Y', errors='coerce')

# %%
columnas_numericas = [
    'poblaci_n_5_16', 'tasa_matriculaci_n_5_16', 'cobertura_neta', 'cobertura_neta_transici_n', 'cobertura_neta_primaria',
    'cobertura_neta_secundaria', 'cobertura_neta_media', 'cobertura_bruta', 'cobertura_bruta_transici_n', 'cobertura_bruta_primaria',
    'cobertura_bruta_secundaria', 'cobertura_bruta_media', 'deserci_n', 'deserci_n_transici_n', 'deserci_n_primaria',
    'deserci_n_secundaria', 'deserci_n_media', 'aprobaci_n', 'aprobaci_n_transici_n', 'aprobaci_n_primaria', 'aprobaci_n_secundaria',
    'aprobaci_n_media', 'reprobaci_n', 'reprobaci_n_transici_n', 'reprobaci_n_primaria', 'reprobaci_n_secundaria', 'reprobaci_n_media',
    'repitencia', 'repitencia_transici_n', 'repitencia_primaria', 'repitencia_secundaria', 'repitencia_media', 'tama_o_promedio_de_grupo',
    'sedes_conectadas_a_internet'
]

# %%
# Dimensión Municipio 
dim_municipio = df_raw[['c_digo_municipio', 'municipio']]
dim_municipio['id_municipio'] = range(1, len(dim_municipio) + 1)  

# Dimensión Departamento 
dim_departamento = df_raw[['c_digo_departamento', 'departamento']]
dim_departamento['id_departamento'] = range(1, len(dim_departamento) + 1)  

# Verificar las dimensiones creadas
display(dim_municipio.head()) 
display(dim_departamento.head())
# Out:
#   c_digo_municipio   municipio  id_municipio
# 0            05004    Abriaquí             1
# 1            95025  El Retorno             2
# 2            95200  Miraflores             3
# 3            97001        Mitú             4
# 4            97161      Caruru             5
#    c_digo_departamento departamento  id_departamento
# 0                   05    Antioquia                1
# 1                   95     Guaviare                2
# 3                   97       Vaupés                3
# 9                   99      Vichada                4
# 14                  94      Guainía                5

# %% [markdown]
# ## Tabla de hechos

# %%
# tabla de hechos 
df_hechos = df_raw[['c_digo_municipio', 'c_digo_departamento', 'a_o'] + columnas_numericas].copy()

# Unir la tabla de hechos con la dimensión Municipio para obtener 'id_municipio'
df_hechos = df_hechos.merge(dim_municipio[['c_digo_municipio', 'id_municipio']], on='c_digo_municipio', how='left')

# Unir la tabla de hechos con la dimensión Departamento para obtener 'id_departamento'
df_hechos = df_hechos.merge(dim_departamento[['c_digo_departamento', 'id_departamento']], on='c_digo_departamento', how='left')

display(df_hechos[['id_municipio', 'id_departamento'] + columnas_numericas].head())
# Out:
#    id_municipio  id_departamento  poblaci_n_5_16  tasa_matriculaci_n_5_16  \
# 0             1                1           503.0                    62.62
# 1             2                2          4438.0                    53.27
# 2             3                2          2014.0                    32.52
# 3             4                3         10986.0                    59.57
# 4             5                3          1228.0                    51.30
#
#    cobertura_neta  cobertura_neta_transici_n  cobertura_neta_primaria  \
# 0           62.62                      44.19                    63.33
# 1           53.27                      33.91                    48.89
# 2           32.52                      17.58                    25.33
# 3           59.57                      42.76                    55.95
# 4           51.30                      76.32                    52.29
#
#    cobertura_neta_secundaria  cobertura_neta_media  cobertura_bruta  \
# 0                      51.53                 40.23            66.80
# 1                      44.90                 21.30            62.98
# 2                      26.43                 10.75            38.58
# 3                      43.51                 17.06            70.65
# 4                      33.71                 11.94            55.54
#
#    cobertura_bruta_transici_n  cobertura_bruta_primaria  \
# 0                       58.14                     72.86
# 1                       54.20                     65.19
# 2                       36.36                     37.28
# 3                       64.90                     76.96
# 4                       92.11                     65.21
#
#    cobertura_bruta_secundaria  cobertura_bruta_media  deserci_n  \
# 0                       66.87                  56.32       1.19
# 1                       69.60                  48.54       5.56
# 2                       46.10                  26.16       7.85
# 3                       72.92                  53.12       3.95
# 4                       51.12                  27.36       8.36
#
#    deserci_n_transici_n  deserci_n_primaria  deserci_n_secundaria  \
# 0                  0.00                1.31                  0.00
# 1                  6.95                4.99                  6.11
# 2                 15.00                8.43                  6.36
# 3                  2.27                1.84                  6.77
# 4                  4.29                3.05                 15.72
#
#    deserci_n_media  aprobaci_n  aprobaci_n_transici_n  aprobaci_n_primaria  \
# 0             4.08       92.26                   0.00                96.73
# 1             5.26       87.67                   0.00                87.90
# 2             4.69       82.68                   3.33                84.64
# 3             5.47       90.71                   0.57                94.12
# 4            14.55       82.40                   0.00                89.63
#
#    aprobaci_n_secundaria  aprobaci_n_media  reprobaci_n  \
# 0                  83.49             93.88         6.55
# 1                  84.50             92.98         6.78
# 2                  79.51             87.50         9.47
# 3                  84.91             89.93         5.34
# 4                  69.00             78.18         9.24
#
#    reprobaci_n_transici_n  reprobaci_n_primaria  reprobaci_n_secundaria  \
# 0                    0.00                  1.96                   16.51
# 1                    0.00                  7.11                    9.39
# 2                    3.33                  6.93                   14.13
# 3                    0.57                  4.04                    8.33
# 4                    0.00                  7.32                   15.28
#
#    reprobaci_n_media  repitencia  repitencia_transici_n  repitencia_primaria  \
# 0               2.04        9.52                   0.00                10.46
# 1               1.75        9.34                   6.95                11.84
# 2               7.81        8.65                   6.67                 9.04
# 3               4.60       16.18                   7.75                21.04
# 4               7.27        9.24                   2.86                 7.62
#
#    repitencia_secundaria  repitencia_media  tama_o_promedio_de_grupo  \
# 0                  13.76              2.04                     23.96
# 1                   8.48              3.16                     23.96
# 2                  10.25              1.54                     23.96
# 3                  13.84              7.18                     23.96
# 4                  14.85              3.64                     23.96
#
#    sedes_conectadas_a_internet
# 0                        28.13
# 1                        28.13
# 2                        28.13
# 3                        28.13
# 4                        28.13

# %%
conn = sqlite3.connect('educacion')
cursor = conn.cursor()

# %%
df_hechos.to_sql('hechos_educacion', conn, if_exists='replace', index=False)
# Out:
# 14582

# %%
def ejecutar_sql(query, conexion=conn):
  """
  Toma una consulta SQL, la ejecuta y devuelve el resultado
  en una tabla de pandas para una visualización clara.
  """
  df = pd.read_sql_query(query, conexion)
  # Usamos display() porque en Colab presenta las tablas de forma más elegante.
  display(df)

# %% [markdown]
# PREGUNTA 1: ¿Qué porcentaje de escolaridad hay respecto a la población del municipio?

# %%
consulta_tasa_matriculacion_municipio = """
    SELECT dm.municipio, 
           he.tasa_matriculaci_n_5_16
    FROM df_hechos AS he
    JOIN dim_municipio AS dm ON he.id_municipio = dm.id_municipio
    ORDER BY he.tasa_matriculaci_n_5_16 DESC;
"""

resultados_tasa_matriculacion_municipio = ejecutar_sql(consulta_tasa_matriculacion_municipio)

print("Tasa de matrícula por municipio (ordenados de mayor a menor):")
print(resultados_tasa_matriculacion_municipio)
# Out:
#              municipio  tasa_matriculaci_n_5_16
# 0      Puerto Colombia                   279.03
# 1      Puerto Colombia                   273.80
# 2      Puerto Colombia                   266.50
# 3                 Cota                   240.70
# 4                 Cota                   239.34
# ...                ...                      ...
# 14577         Papunaua                     0.00
# 14578         Papunaua                     0.00
# 14579         Papunaua                     0.00
# 14580      La Victoria                     0.00
# 14581         Papunaua                     0.00
#
# [14582 rows x 2 columns]
# Tasa de matrícula por municipio (ordenados de mayor a menor):
# None

# %%
consulta_esquema = "PRAGMA table_info(hechos_educacion);"
resultados_esquema = ejecutar_sql(consulta_esquema)
print("Esquema de la tabla hechos_educacion:")
print(resultados_esquema)
# Out:
#     cid                         name       type  notnull dflt_value  pk
# 0     0             c_digo_municipio       TEXT        0       None   0
# 1     1          c_digo_departamento       TEXT        0       None   0
# 2     2                          a_o  TIMESTAMP        0       None   0
# 3     3               poblaci_n_5_16       REAL        0       None   0
# 4     4      tasa_matriculaci_n_5_16       REAL        0       None   0
# 5     5               cobertura_neta       REAL        0       None   0
# 6     6    cobertura_neta_transici_n       REAL        0       None   0
# 7     7      cobertura_neta_primaria       REAL        0       None   0
# 8     8    cobertura_neta_secundaria       REAL        0       None   0
# 9     9         cobertura_neta_media       REAL        0       None   0
# 10   10              cobertura_bruta       REAL        0       None   0
# 11   11   cobertura_bruta_transici_n       REAL        0       None   0
# 12   12     cobertura_bruta_primaria       REAL        0       None   0
# 13   13   cobertura_bruta_secundaria       REAL        0       None   0
# 14   14        cobertura_bruta_media       REAL        0       None   0
# 15   15                    deserci_n       REAL        0       None   0
# 16   16         deserci_n_transici_n       REAL        0       None   0
# 17   17           deserci_n_primaria       REAL        0       None   0
# 18   18         deserci_n_secundaria       REAL        0       None   0
# 19   19              deserci_n_media       REAL        0       None   0
# 20   20                   aprobaci_n       REAL        0       None   0
# 21   21        aprobaci_n_transici_n       REAL        0       None   0
# 22   22          aprobaci_n_primaria       REAL        0       None   0
# 23   23        aprobaci_n_secundaria       REAL        0       None   0
# 24   24             aprobaci_n_media       REAL        0       None   0
# 25   25                  reprobaci_n       REAL        0       None   0
# 26   26       reprobaci_n_transici_n       REAL        0       None   0
# 27   27         reprobaci_n_primaria       REAL        0       None   0
# 28   28       reprobaci_n_secundaria       REAL        0       None   0
# 29   29            reprobaci_n_media       REAL        0       None   0
# 30   30                   repitencia       REAL        0       None   0
# 31   31        repitencia_transici_n       REAL        0       None   0
# 32   32          repitencia_primaria       REAL        0       None   0
# 33   33        repitencia_secundaria       REAL        0       None   0
# 34   34             repitencia_media       REAL        0       None   0
# 35   35     tama_o_promedio_de_grupo       REAL        0       None   0
# 36   36  sedes_conectadas_a_internet       REAL        0       None   0
# 37   37                 id_municipio    INTEGER        0       None   0
# 38   38              id_departamento    INTEGER        0       None   0
# Esquema de la tabla hechos_educacion:
# None

# %% [markdown]
# 2. ¿Cómo compararía el rendimiento educativo por municipios?

# %%
# Consulta para comparar el rendimiento educativo por municipio
consulta_2 = """
SELECT 
    c_digo_municipio AS codigo_municipio,
    a_o,
    aprobaci_n AS tasa_aprobacion
FROM hechos_educacion
WHERE aprobaci_n IS NOT NULL
ORDER BY c_digo_municipio, a_o;
"""

resultados_rendimiento_educativo = ejecutar_sql(consulta_2)
# Out:
#       codigo_municipio                  a_o  tasa_aprobacion
# 0                05001  2023-01-01 00:00:00            85.37
# 1                05002  2023-01-01 00:00:00            88.08
# 2                05004  2023-01-01 00:00:00            92.26
# 3                05021  2023-01-01 00:00:00            88.86
# 4                05030  2023-01-01 00:00:00            84.95
# ...                ...                  ...              ...
# 14577            99773  2019-01-01 00:00:00            70.06
# 14578            99773  2020-01-01 00:00:00            80.27
# 14579            99773  2021-01-01 00:00:00            73.55
# 14580            99773  2022-01-01 00:00:00            72.73
# 14581            99773  2023-01-01 00:00:00            76.05
#
# [14582 rows x 3 columns]

# %% [markdown]
# 3. ¿Que departamentos son los que mejor cobertura tienen? ¿Pueden hacer cálculo con SQL?

# %%
consulta_3 = """
SELECT 
    c_digo_departamento AS codigo_departamento,
    ROUND(AVG(cobertura_neta), 2) AS cobertura_promedio
FROM hechos_educacion
WHERE cobertura_neta IS NOT NULL
GROUP BY c_digo_departamento
ORDER BY cobertura_promedio DESC;
"""

resultados_mejor_cobertura_departamentos = ejecutar_sql(consulta_3)
# Out:
#    codigo_departamento  cobertura_promedio
# 0                   63               94.58
# 1                   70               93.85
# 2                   20               93.73
# 3                   47               93.27
# 4                   50               90.65
# 5                   11               89.49
# 6                   73               89.24
# 7                   25               88.55
# 8                   85               88.53
# 9                    5               88.43
# 10                  23               88.04
# 11                   8               87.93
# 12                  13               87.47
# 13                  68               87.08
# 14                  41               86.46
# 15                  66               86.10
# 16                  15               84.54
# 17                  05               84.14
# 18                  17               84.11
# 19                  54               83.67
# 20                  08               83.31
# 21                  76               83.25
# 22                  81               82.41
# 23                  88               82.22
# 24                  44               81.73
# 25                  27               80.90
# 26                  86               80.88
# 27                  99               80.67
# 28                  19               79.55
# 29                  52               78.07
# 30                  18               77.63
# 31                  94               65.48
# 32                  91               63.49
# 33                  95               62.20
# 34                  97               59.88
